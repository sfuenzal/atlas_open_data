# %%
import matplotlib.pyplot as plt
import numpy as np
import uproot

# %%
dataA = uproot.open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/2lep/Data/data_A.2lep.root")
dataB = uproot.open("https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/2lep/Data/data_B.2lep.root")

# %%
print(dataA.keys())
print(dataB.keys())
# Out:
# [b'mini;1']
# [b'mini;1']

# %%
treeA = dataA['mini']
treeB = dataB['mini']

# %%
treeA.keys()
# Out:
# [b'runNumber',
#  b'eventNumber',
#  b'channelNumber',
#  b'mcWeight',
#  b'scaleFactor_PILEUP',
#  b'scaleFactor_ELE',
#  b'scaleFactor_MUON',
#  b'scaleFactor_PHOTON',
#  b'scaleFactor_TAU',
#  b'scaleFactor_BTAG',
#  b'scaleFactor_LepTRIGGER',
#  b'scaleFactor_PhotonTRIGGER',
#  b'trigE',
#  b'trigM',
#  b'trigP',
#  b'lep_n',
#  b'lep_truthMatched',
#  b'lep_trigMatched',
#  b'lep_pt',
#  b'lep_eta',
#  b'lep_phi',
#  b'lep_E',
#  b'lep_z0',
#  b'lep_charge',
#  b'lep_type',
#  b'lep_isTightID',
#  b'lep_ptcone30',
#  b'lep_etcone20',
#  b'lep_trackd0pvunbiased',
#  b'lep_tracksigd0pvunbiased',
#  b'met_et',
#  b'met_phi',
#  b'jet_n',
#  b'jet_pt',
#  b'jet_eta',
#  b'jet_phi',
#  b'jet_E',
#  b'jet_jvt',
#  b'jet_trueflav',
#  b'jet_truthMatched',
#  b'jet_MV2c10',
#  b'photon_n',
#  b'photon_truthMatched',
#  b'photon_trigMatched',
#  b'photon_pt',
#  b'photon_eta',
#  b'photon_phi',
#  b'photon_E',
#  b'photon_isTightID',
#  b'photon_ptcone30',
#  b'photon_etcone20',
# ...

# %% [markdown]
# # Transverse momentum $p_T$ and energy $E$ of the leptons

# %%
lep_pt_data_A = np.array(treeA.array(['lep_pt']))

# %%
lep_pt_data_B = np.array(treeB.array(['lep_pt']))

# %%
lep_pt_data_A_col_0_list = []
for i in range(len(lep_pt_data_A)):
    lep_pt_data_A_col_0_list.append(lep_pt_data_A[i][0])

lep_pt_data_A_col_0 = np.array(lep_pt_data_A_col_0_list)

lep_pt_data_A_col_1_list = []
for i in range(len(lep_pt_data_A)):
    lep_pt_data_A_col_1_list.append(lep_pt_data_A[i][1])

lep_pt_data_A_col_1 = np.array(lep_pt_data_A_col_1_list)

# %%
lep_pt_data_B_col_0_list = []
for i in range(len(lep_pt_data_B)):
    lep_pt_data_B_col_0_list.append(lep_pt_data_B[i][0])

lep_pt_data_B_col_0 = np.array(lep_pt_data_B_col_0_list)

lep_pt_data_B_col_1_list = []
for i in range(len(lep_pt_data_B)):
    lep_pt_data_B_col_1_list.append(lep_pt_data_B[i][1])

lep_pt_data_B_col_1 = np.array(lep_pt_data_B_col_1_list)

# %%
lep_E_data_A = np.array(treeA.array(['lep_E']))

# %%
lep_E_data_B = np.array(treeB.array(['lep_E']))

# %%
lep_E_data_A_col_0_list = []
for i in range(len(lep_E_data_A)):
    lep_E_data_A_col_0_list.append(lep_E_data_A[i][0])

lep_E_data_A_col_0 = np.array(lep_E_data_A_col_0_list)

lep_E_data_A_col_1_list = []
for i in range(len(lep_E_data_A)):
    lep_E_data_A_col_1_list.append(lep_E_data_A[i][1])

lep_E_data_A_col_1 = np.array(lep_E_data_A_col_1_list)

# %%
lep_E_data_B_col_0_list = []
for i in range(len(lep_E_data_B)):
    lep_E_data_B_col_0_list.append(lep_E_data_B[i][0])

lep_E_data_B_col_0 = np.array(lep_E_data_B_col_0_list)

lep_E_data_B_col_1_list = []
for i in range(len(lep_E_data_B)):
    lep_E_data_B_col_1_list.append(lep_E_data_B[i][1])

lep_E_data_B_col_1 = np.array(lep_E_data_B_col_1_list)

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))

axs[0, 0].scatter(lep_pt_data_A_col_1, lep_pt_data_A_col_0, marker = 'x', color = 'red')
axs[0, 0].set_title(r'$p_T$ for data_A.root', fontsize = 18)
axs[0, 0].set_xlabel(r'$p_{T\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 0].set_ylabel(r'$p_{T\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].grid()

axs[0, 1].scatter(lep_pt_data_B_col_1, lep_pt_data_B_col_0, marker = 'x', color = 'blue')
axs[0, 1].set_title(r'$p_T$ for data_B.root', fontsize = 18)
axs[0, 1].set_xlabel(r'$p_{T\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].set_ylabel(r'$p_{T\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 1].grid()

axs[1, 0].scatter(lep_E_data_A_col_1, lep_E_data_A_col_0, marker = 'x', color = 'red')
axs[1, 0].set_title(r'$E$ for data_A.root', fontsize = 18)
axs[1, 0].set_xlabel(r'$E_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 0].set_ylabel(r'$E_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].grid()

axs[1, 1].scatter(lep_E_data_B_col_1, lep_E_data_B_col_0, marker = 'x', color = 'blue')
axs[1, 1].set_title(r'$E$ for data_B.root', fontsize = 18)
axs[1, 1].set_xlabel(r'$E_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].set_ylabel(r'$E_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 1].grid()

plt.savefig('HtoWW_analysis_pT_and_E_plots_data_A_and_B.png')

# %% [markdown]
# # Pseudo-rapidity $\eta$ and azimuthal angle $\phi$ of the leptons

# %%
lep_eta_data_A = np.array(treeA.array(['lep_eta']))

# %%
lep_eta_data_B = np.array(treeB.array(['lep_eta']))

# %%
lep_eta_data_A_col_0_list = []
for i in range(len(lep_eta_data_A)):
    lep_eta_data_A_col_0_list.append(lep_eta_data_A[i][0])

lep_eta_data_A_col_0 = np.array(lep_eta_data_A_col_0_list)

lep_eta_data_A_col_1_list = []
for i in range(len(lep_eta_data_A)):
    lep_eta_data_A_col_1_list.append(lep_eta_data_A[i][1])

lep_eta_data_A_col_1 = np.array(lep_eta_data_A_col_1_list)

# %%
lep_eta_data_B_col_0_list = []
for i in range(len(lep_eta_data_B)):
    lep_eta_data_B_col_0_list.append(lep_eta_data_B[i][0])

lep_eta_data_B_col_0 = np.array(lep_eta_data_B_col_0_list)

lep_eta_data_B_col_1_list = []
for i in range(len(lep_eta_data_B)):
    lep_eta_data_B_col_1_list.append(lep_eta_data_B[i][1])

lep_eta_data_B_col_1 = np.array(lep_eta_data_B_col_1_list)

# %%
lep_phi_data_A = np.array(treeA.array(['lep_phi']))

# %%
lep_phi_data_B = np.array(treeB.array(['lep_phi']))

# %%
lep_phi_data_A_col_0_list = []
for i in range(len(lep_phi_data_A)):
    lep_phi_data_A_col_0_list.append(lep_phi_data_A[i][0])

lep_phi_data_A_col_0 = np.array(lep_phi_data_A_col_0_list)

lep_phi_data_A_col_1_list = []
for i in range(len(lep_phi_data_A)):
    lep_phi_data_A_col_1_list.append(lep_phi_data_A[i][1])

lep_phi_data_A_col_1 = np.array(lep_phi_data_A_col_1_list)

# %%
lep_phi_data_B_col_0_list = []
for i in range(len(lep_phi_data_B)):
    lep_phi_data_B_col_0_list.append(lep_phi_data_B[i][0])

lep_phi_data_B_col_0 = np.array(lep_phi_data_B_col_0_list)

lep_phi_data_B_col_1_list = []
for i in range(len(lep_phi_data_B)):
    lep_phi_data_B_col_1_list.append(lep_phi_data_B[i][1])

lep_phi_data_B_col_1 = np.array(lep_phi_data_B_col_1_list)

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))

axs[0, 0].scatter(lep_eta_data_A_col_0, lep_pt_data_A_col_0, marker = 'x', color = 'red')
axs[0, 0].set_title(r'$\eta$ versus $p_T$ for data_A.root (column 0)', fontsize = 18)
axs[0, 0].set_xlabel(r'$\eta_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].set_ylabel(r'$p_{T\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].grid()

axs[0, 1].scatter(lep_eta_data_A_col_1, lep_pt_data_A_col_1, marker = 'x', color = 'blue')
axs[0, 1].set_title(r'$\eta$ versus $p_T$ for data_A.root (column 1)', fontsize = 18)
axs[0, 1].set_xlabel(r'$\eta_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].set_ylabel(r'$p_{T\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].grid()

axs[1, 0].scatter(lep_eta_data_A_col_0, lep_E_data_A_col_0, marker = 'x', color = 'red')
axs[1, 0].set_title(r'$\eta$ versus $E$ for data_A.root (column 0)', fontsize = 18)
axs[1, 0].set_xlabel(r'$\eta_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].set_ylabel(r'$E_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].grid()

axs[1, 1].scatter(lep_eta_data_A_col_1, lep_E_data_A_col_1, marker = 'x', color = 'blue')
axs[1, 1].set_title(r'$\eta$ versus $E$ for data_A.root (column 1)', fontsize = 18)
axs[1, 1].set_xlabel(r'$\eta_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].set_ylabel(r'$E_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].grid()

plt.savefig('HtoWW_analysis_eta_plots_data_A.png')

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))

axs[0, 0].scatter(lep_eta_data_B_col_0, lep_pt_data_B_col_0, marker = 'x', color = 'red')
axs[0, 0].set_title(r'$\eta$ versus $p_T$ for data_B.root (column 0)', fontsize = 18)
axs[0, 0].set_xlabel(r'$\eta_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].set_ylabel(r'$p_{T\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].grid()

axs[0, 1].scatter(lep_eta_data_B_col_1, lep_pt_data_B_col_1, marker = 'x', color = 'blue')
axs[0, 1].set_title(r'$\eta$ versus $p_T$ for data_B.root (column 1)', fontsize = 18)
axs[0, 1].set_xlabel(r'$\eta_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].set_ylabel(r'$p_{T\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].grid()

axs[1, 0].scatter(lep_eta_data_B_col_0, lep_E_data_B_col_0, marker = 'x', color = 'red')
axs[1, 0].set_title(r'$\eta$ versus $E$ for data_B.root (column 0)', fontsize = 18)
axs[1, 0].set_xlabel(r'$\eta_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].set_ylabel(r'$E_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].grid()

axs[1, 1].scatter(lep_eta_data_B_col_1, lep_E_data_B_col_1, marker = 'x', color = 'blue')
axs[1, 1].set_title(r'$\eta$ versus $E$ for data_B.root (column 1)', fontsize = 18)
axs[1, 1].set_xlabel(r'$\eta_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].set_ylabel(r'$E_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].grid()

plt.savefig('HtoWW_analysis_eta_plots_data_B.png')

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))

axs[0, 0].scatter(lep_phi_data_A_col_0, lep_pt_data_A_col_0, marker = 'x', color = 'red')
axs[0, 0].set_title(r'$\phi$ versus $p_T$ for data_A.root (column 0)', fontsize = 18)
axs[0, 0].set_xlabel(r'$\phi_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].set_ylabel(r'$p_{T\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].grid()

axs[0, 1].scatter(lep_phi_data_A_col_1, lep_pt_data_A_col_1, marker = 'x', color = 'blue')
axs[0, 1].set_title(r'$\phi$ versus $p_T$ for data_A.root (column 1)', fontsize = 18)
axs[0, 1].set_xlabel(r'$\phi_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].set_ylabel(r'$p_{T\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].grid()

axs[1, 0].scatter(lep_phi_data_A_col_0, lep_E_data_A_col_0, marker = 'x', color = 'red')
axs[1, 0].set_title(r'$\phi$ versus $E$ for data_A.root (column 0)', fontsize = 18)
axs[1, 0].set_xlabel(r'$\phi_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].set_ylabel(r'$E_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].grid()

axs[1, 1].scatter(lep_phi_data_A_col_1, lep_E_data_A_col_1, marker = 'x', color = 'blue')
axs[1, 1].set_title(r'$\phi$ versus $E$ for data_A.root (column 1)', fontsize = 18)
axs[1, 1].set_xlabel(r'$\phi_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].set_ylabel(r'$E_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].grid()

plt.savefig('HtoWW_analysis_phi_plots_data_A.png')

# %%
fig, axs = plt.subplots(2, 2, figsize = (15,15))

axs[0, 0].scatter(lep_phi_data_B_col_0, lep_pt_data_B_col_0, marker = 'x', color = 'red')
axs[0, 0].set_title(r'$\phi$ versus $p_T$ for data_B.root (column 0)', fontsize = 18)
axs[0, 0].set_xlabel(r'$\phi_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].set_ylabel(r'$p_{T\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[0, 0].grid()

axs[0, 1].scatter(lep_phi_data_B_col_1, lep_pt_data_B_col_1, marker = 'x', color = 'blue')
axs[0, 1].set_title(r'$\phi$ versus $p_T$ for data_B.root (column 1)', fontsize = 18)
axs[0, 1].set_xlabel(r'$\phi_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].set_ylabel(r'$p_{T\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[0, 1].grid()

axs[1, 0].scatter(lep_phi_data_B_col_0, lep_E_data_B_col_0, marker = 'x', color = 'red')
axs[1, 0].set_title(r'$\phi$ versus $E$ for data_B.root (column 0)', fontsize = 18)
axs[1, 0].set_xlabel(r'$\phi_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].set_ylabel(r'$E_{\mathrm{\ Column\ 0}}$', fontsize = 18)
axs[1, 0].grid()

axs[1, 1].scatter(lep_phi_data_B_col_1, lep_E_data_B_col_1, marker = 'x', color = 'blue')
axs[1, 1].set_title(r'$\phi$ versus $E$ for data_B.root (column 1)', fontsize = 18)
axs[1, 1].set_xlabel(r'$\phi_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].set_ylabel(r'$E_{\mathrm{\ Column\ 1}}$', fontsize = 18)
axs[1, 1].grid()

plt.savefig('HtoWW_analysis_phi_plots_data_B.png')

# %% [markdown]
# # Charge of the leptons

# %%
lep_charge_data_A = np.array(treeA.array(['lep_charge']))

# %%
lep_charge_data_B = np.array(treeB.array(['lep_charge']))

# %%
lep_charge_data_A_col_0_list = []
for i in range(len(lep_charge_data_A)):
    lep_charge_data_A_col_0_list.append(lep_charge_data_A[i][0])

lep_charge_data_A_col_0 = np.array(lep_charge_data_A_col_0_list)

lep_charge_data_A_col_1_list = []
for i in range(len(lep_charge_data_A)):
    lep_charge_data_A_col_1_list.append(lep_charge_data_A[i][1])

lep_charge_data_A_col_1 = np.array(lep_charge_data_A_col_1_list)

# %%
lep_charge_data_B_col_0_list = []
for i in range(len(lep_charge_data_B)):
    lep_charge_data_B_col_0_list.append(lep_charge_data_B[i][0])

lep_charge_data_B_col_0 = np.array(lep_charge_data_B_col_0_list)

lep_charge_data_B_col_1_list = []
for i in range(len(lep_charge_data_B)):
    lep_charge_data_B_col_1_list.append(lep_charge_data_B[i][1])

lep_charge_data_B_col_1 = np.array(lep_charge_data_B_col_1_list)
